# %% [markdown]
# # SOME BASIC INFO.

# %% [markdown]
# ## Python vs Other Languages
#
# Let's create a simple statement that says:
# "If a is greater than b, assign 2 to a and 4 to b"
#
# Take a look at these two if statements (we will learn about building out if statements soon).
#
# **Version 1 (Other Languages)**
#
#     if (a>b){
#         a = 2;
#         b = 4;
#     }
#
# **Version 2 (Python)**
#
#     if a>b:
#         a = 2
#         b = 4

# %% [markdown]
# ## You'll notice that Python is less cluttered and much more readable than the first version. How does Python manage this?
#
# the main differences:
#
# Python gets rid of () and {} by incorporating two main factors: a *colon* and *whitespace*. The statement is ended with a colon, and whitespace is used (indentation) to describe what takes place in case of the statement.
#
# Another major difference is the lack of semicolons in Python. Semicolons are used to denote statement endings in many other languages, but in Python, the end of a line is the same as the end of a statement.
#
# Lastly, to end this brief overview of differences, let's take a closer look at indentation syntax in Python vs other languages:
#
# ## Indentation
#
# Here is some pseudo-code to indicate the use of whitespace and indentation in Python:
#
# **Other Languages**
#
#     if (x)
#         if(y)
#             code-statement;
#     else
#         another-code-statement;
#
# **Python**
#
#     if x:
#         if y:
#             code-statement
#     else:
#         another-code-statement

# %% [markdown]
# Note how Python is so heavily driven by code indentation and whitespace. This means that code readability is a core part of the design of the Python language.
#
# Now let's start diving deeper by coding these sort of statements in Python!

# %% [markdown]
# # if, elif, else Statements
#
# <code>if</code> Statements in Python allows us to tell the computer to perform alternative actions based on a certain set of results.
#
# Verbally, we can imagine we are telling the computer:
#
# "Hey if this case happens, perform some action"
#
# We can then expand the idea further with <code>elif</code> and <code>else</code> statements, which allow us to tell the computer:
#
# "Hey if this case happens, perform some action. Else, if another case happens, perform some other action. Else, if *none* of the above cases happened, perform this action."
#
# Let's go ahead and look at the syntax format for <code>if</code> statements to get a better idea of this:
#
#     if case1:
#         perform action1
#     elif case2:
#         perform action2
#     else:
#         perform action3

# %% [markdown]
# # Flow Diagram

# %% [markdown]
# ![Screenshot%202021-10-21%20at%2019-37-55%20Python%20IF%20ELIF%20ELSE%20Statements%20pdf.png](attachment:Screenshot%202021-10-21%20at%2019-37-55%20Python%20IF%20ELIF%20ELSE%20Statements%20pdf.png)

# %% [markdown]
# ## First Example
#
# Let's see a quick example of this:

# %%
if True :
    print("correct answer")
# Out:
# correct answer

# %%
if 3>2 :
    print("right")
# if 3 is greater than 2 than print right
# Out:
# right

# %%
if 3<2 :
    print("right")
# if 3 is not greater than 2 it does not gives any output or error

# %%
name = "ayush"
if name :
    print("it is correct name")
# Out:
# it is correct name

# %%
if name == "aaa" :
    print("it is correct name")
# here it say that if name = aaa than output should same as pervious 
# but it was not because we already define name = ayush 
# so if you try for another name than it will donot going to show you the output

# %% [markdown]
# Let's add in some else logic:

# %%
a = False
if a :
    print("if statemnet work for true ")
else : 
        print("the statement is flase ")
# Out:
# the statement is flase

# %% [markdown]
#     here you can see `if` statement work when the value said to be true
#      and if the value was wrong than `else` statement works
#
#      NOTE : you should type else/elif statement after indentation (whitespaces)
#      because not than python will understand as under `if` statement
#
#      so let see with a example

# %%
a = False
if a :
    print("x")
    else : 
        print("t")
# Out:
#   File "<ipython-input-43-67b4a9356cef>", line 4
#     else :
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##  Multiple Branches
#
# Let's get a fuller picture of how far <code>if</code>, <code>elif</code>, and <code>else</code> can take us!
#
# We write this out in a nested structure. Take note of how the <code>if</code>, <code>elif</code>, and <code>else</code> line up in the code. This can help you see what <code>if</code> is related to what <code>elif</code> or <code>else</code> statements.
#
# We'll reintroduce a comparison syntax for Python.

# %%
age = 19 
if age == 20 :
    print("age of kajal")
elif age == 19 :
    print("age of mine")
else :
    print ("type your correct age")
# Out:
# age of mine

# %%
age = 20
if age == 20 :
    print("age of kajal")
elif age == 19 :
    print("age of mine")
else :
    print ("type you correct age")
# Out:
# age of kajal

# %%
age = 28
if age == 20 :
    print("age of kajal")
elif age == 19 :
    print("age of mine")
else :
    print ("type your correct age")
# Out:
# type your correct age

# %%
area = "rampura"
if area == "harsh nagar":
    print("that is your area")
elif area == "sisarama" :
    print ("its is your landmark")
elif area == "ambamata":
    print("this your police station location")
else :
    print("worng location")
# Out:
# worng location

# %%
area = "harsh nagar"
if area == "harsh nagar":
    print("that is your area")
elif area == "sisarama" :
    print ("its is your landmark")
elif area == "ambamata":
    print("this your police station location")
else :
    print("worng location")
# Out:
# that is your area

# %%
person = 'ayush'

if person == 'jay':
    print('Welcome jay!')
elif person =='ayush':
    print('Welcome ayush!')
else:
    print("Welcome, what's your name?")
# Out:
# Welcome ayush!

# %%
person = 'bill'

if person == 'jay':
    print('Welcome jay!')
elif person =='ayush':
    print('Welcome ayush!')
else:
    print("Welcome, what's your name?")
# Out:
# Welcome, what's your name?

# %%
y = 2 
if (y == 1) :
    print("one")
elif (y == 2) :
    print("two")
# Out:
# two

# %% [markdown]
# here you can also put value in () on `if` & `else` statement

# %%
t_shirt_color = "yellow"
if (t_shirt_color == "grey") :
    print("you have 2 t-shirt of this color")
elif t_shirt_color == "yellow":
    print ("you have only 1 t-shirt of this color")
elif (t_shirt_color == "black"):
    print("you have more than 2 t-shirt of this color")
else :
    print("Buy A New One !")
# Out:
# you have only 1 t-shirt of this color
