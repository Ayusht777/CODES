# %% [markdown]
# # Dictionaries

# %% [raw]
# As of Python version 3.7, dictionaries are ordered. In Python 3.6 and earlier,dictionaries are unordered.
#
#
# Q1.)Ordered or Unordered?
#
# ans)When we say that dictionaries are ordered, it means that the items have a defined order, and that order will not change.
# -----------------------------------------------------------------------------------------------------------------------
# Unordered means that the items does not have a defined order, you cannot refer to an item by using an index.
# dictionaries are order mapping for sorting list object's
#
# basically
# list store the value in sequence and by their index positions
# but dictionaries are order and they have key which store a value
#      list =[1,2,3]
#             | | |
#     index-->0 1 2
#
#     dicte = a{'key1':'value','key4':'value2'}  note here  key and value both are strings
#              |           |
#   these key1 = value
#         key4 = value2  so it doesnot requierd to provide info by using indexing via knowing its position

# %% [markdown]
# We've been learning about *sequences* in Python but now we're going to switch gears and learn about *mappings* in Python. If you're familiar with other languages you can think of these Dictionaries as hash tables.

# %% [markdown]
# So what are mappings? Mappings are a collection of objects that are stored by a *key*, unlike a sequence that stored objects by their relative position. This is an important distinction, since mappings won't retain order since they have objects defined by a key.

# %% [markdown]
# ## Constructing a Dictionary

# %% [markdown]
# method:
#     dic = {"key1":"value1","key2":"value2"}
#
#
# NOTE : DICTIONARIES ARE CASE SENSITIVE,KEYS CANNOT BE REPEATED IF YOU REUSE A KEY THAN IT GOING TO OVERWRITE THE PERVIOUS ONE

# %%
name_wise_wieght = {"ashok":"75 kg","ayush":"85 kg","kajal":"65 kg","aanchal":"82 kg"}

# %%
name_wise_wieght
# Out:
# {'ashok': '75 kg', 'ayush': '85 kg', 'kajal': '65 kg', 'aanchal': '82 kg'}

# %%
# Call values by their key

# %%
name_wise_wieght["ayush"]
# Out:
# '85 kg'

# %%
name_wise_wieght["kajal"]
# Out:
# '65 kg'

# %%
prices_of_footwear = {"slippers":250,"shoes":999,"lady slippers":150}

# %%
prices_of_footwear["shoes"]
# Out:
# 999

# %%
# also remember to use [""/''] to get a value of a key

# %%
prices_of_footwear[shoes]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-38524d035e52> in <module>
# ----> 1 prices_of_footwear[shoes]
#
# NameError: name 'shoes' is not defined

# %% [markdown]
# dictionaries are very felxible and so they can hold various data types like: strings,integers,floating point,list,tuples,dictionaries,list.etc

# %%
various_data_types = {"string":"a","intger":99,"floating point":5.1,"lists":[1,2],"dicts":{"k1":"new","k2":"old"}}

# %%
various_data_types["lists"]
# Out:
# [1, 2]

# %%
#lets grab a items from lists

# %%
various_data_types["lists"][1]
# Out:
# 2

# %%
#here first [] for key and second [] for value at particluar index

# %%
#lets grab a items from dicts

# %%
various_data_types["dicts"]["k1"]
# Out:
# 'new'

# %% [markdown]
# here
# dicts is a key
# and k1,k2 is sub keys and aslo a value for dicts
# and new,old is sub value for k1,k2

# %% [markdown]
# #### We can affect the values of a key as well. For instance:

# %%
n_dicts = {"k1":"old ","k2":"new"}

# %%
n_dicts["k1"] = n_dicts["k1"] + "gold"

# %%
n_dicts
# Out:
# {'k1': 'old gold', 'k2': 'new'}

# %%
#another example

# %%
int_dicts = {"N1":112,"N2":131}

# %%
int_dicts["N1"] = int_dicts["N1"] - 1

# %%
int_dicts               # its is permanet because we use  =  above
# Out:
# {'N1': 111, 'N2': 131}

# %% [markdown]
# A quick note, Python has a built-in method of doing a self subtraction/addition/multiplication/division.
#
# We could have also used `+=` or `-=` for the above statement. For example:

# %%
int_dicts["N1"] += 1

# %%
int_dicts
# Out:
# {'N1': 112, 'N2': 131}

# %%
#now using string built-in method for dictionaries

# %%
letter_word = {"a":"apple","b":"boy","c":"cat"}

# %%
letter_word["a"].upper()
# Out:
# 'APPLE'

# %%
letter_word["b"].capitalize()
# Out:
# 'Boy'

# %%
#adding new key value in dictionaries

# %%
alpha = {"x":0,"y":2}

# %%
alpha["z"]=3

# %%
alpha
# Out:
# {'x': 0, 'y': 2, 'z': 3}

# %%
# adding multiple value to dicitonaries at a same time  (refer update() method in built in section)

# %%
#overwritting a dicitonaries key values

# %%
alpha["z"] = 44

# %%
alpha
# Out:
# {'x': 0, 'y': 2, 'z': 44}

# %%
#overwritting a dicitonaries key values

# %%
biodata = {'name':'ayush','years':19}

# %%
biodata ['years'] = biodata ['age']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-81de09a71d52> in <module>
# ----> 1 biodata ['years'] = biodata ['age']
#
# KeyError: 'age'

# %%
d = {'foo': 100, 'bar': 200, 'baz': 300}

# %%
d['bar':'baz']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-21c40bd6081b> in <module>
# ----> 1 d['bar':'baz']
#
# TypeError: unhashable type: 'slice'

# %%
#createing a empty dicitonaries and adding itmes later

# %%
animals = {}

# %%
animals["birds"] = "egale"

# %%
animals["dogs"] = "pug"

# %%
animals
# Out:
# {'dogs': 'pug', 'birds': 'egale'}

# %% [markdown]
# Q2.) Duplicates Not Allowed ?
#
# ans) Dictionaries cannot have two items with the same key:

# %% [markdown]
# ### Dicitionaries Built-In Method

# %%
animals.keys()    #to get all keys
# Out:
# dict_keys(['birds', 'dogs'])

# %%
animals.values()  #to get all key values
# Out:
# dict_values(['egale', 'pug'])

# %%
animals.items() #to get all items in a dictionares
# Out:
# dict_items([('birds', 'egale'), ('dogs', 'pug')])

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------

# %%
'''.get() method will going to show the key or value is present in the dictionary or not & 
by not means it will not give an error if key / value is not present'''
# Out:
# '.get() method will going to show the key or value is present in the dictionary or not & \nby not means it will not give an error if key / value is not present'

# %%
dicts = {"name":"ayush","age":19}

# %%
dicts.get("name")
# Out:
# 'ayush'

# %%
#for the key/value which is not present in the dictionary

# %%
print(dicts.get("gender"))  #use print () here,if not it will show blank output
# Out:
# None

# %%
print(dicts.get("years",19))
# Out:
# 19

# %%
#But if key is not in the dictionary, the method can returns a specified default.by us

# %% [markdown]
# real use if we made a app and provide a data of names of children in class and when we use this app and try to search amy another name out of the name list than you can show a specific output like name is not present in it or none
# rather than a error

# %% [markdown]
# Note: items() method is similar to dictionary's viewitems() method in Python 2.7. which does not work now

# %%
animals.pop("birds") # to remove a specifiec key from a dicitionaries
animals              #and it is permanent
# Out:
# {'dogs': 'pug'}

# %% [markdown]
# #                      or

# %%
furit_s = {"green":"apple","yellow":"banna"}

# %%
furit_s.popitem()           # it will going to remove last key and value from dictionary same as .pop() method
                            # it is also permanent
# Out:
# ('yellow', 'banna')

# %%
print(furit_s)
# Out:
# {'green': 'apple'}

# %%
person = {'name': 'Phill', 'age': 22, 'salary': 3500.0}

# %%
person.popitem()
print(person)
# Out:
# {'name': 'Phill', 'age': 22}

# %% [markdown]
# The update() method will updates the dictionary with the elements from another dictionary object or from a pervious dictionary by using it

# %%
a = {"x":1,"y":2}

# %%
b = {"z":3}

# %%
a.update(b)

# %%
a
# Out:
# {'x': 1, 'y': 2, 'z': 3}

# %%
a.update({"X":5,"w":0})
print(a)
# Out:
# {'x': 1, 'y': 2, 'X': 5, 'w': 0}

# %% [markdown]
# here i want to add keys of b into a so i use .update method and it is also permanent

# %%
#.clear() method 
#Removes all items from the dictionary.

# %%
d = {"a":1,"b":2}

# %%
d.clear()
print(d)
# Out:
# {}

# %% [markdown]
# ## or

# %%
#you can use del method

# %%
del d

# %%
print(d)
#error because we delete this item from the notebook ,so we use clear method to get a clear list without a error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-6bb4a6436713> in <module>
# ----> 1 print(d)
#       2 #error because we delete this item from the notebook ,so we use clear method to get a clear list without a error
#
# NameError: name 'd' is not defined

# %%
#.copy() method
#They copy() method returns a copy (shallow copy) of the dictionary.

# %%
orignal = {"z":2,"y":7}

# %%
copydict = orignal.copy()

# %%
copydict
# Out:
# {'z': 2, 'y': 7}

# %% [raw]
# # .formkeys(keys,defaultvalue) method
# #this method will going to add same value for all diffrent keys
# METHOD :
# dict1 = {"x","y","z"}  ----->> Dictionary
# num = [1,2,3]         ------>> list   {value can be list,string,int,folat
# merge = dict.fromkeys(dicts,num)

# %%
blood = {"a","k"}
blood_type = 'A+'

# %%
blood_group = dict.fromkeys(blood,blood_type)

# %%
blood_group
# Out:
# {'k': 'A+', 'a': 'A+'}

# %% [markdown]
# ### .setdefault() method
# The setdefault() method returns the value of a key (if the key is in dictionary).
#
# If not, it inserts key with a value to the dictionary.

# %%
dicts = {"name":"ayush","rollno":14,"class":"btech"}

# %%
dicts.setdefault("name")  #so the key is present with a value
# Out:
# 'ayush'

# %%
dicts.setdefault(14)  #adding a key and its value by default would be none

# %%
dicts
# Out:
# {'name': 'ayush', 'rollno': 14, 'class': 'btech', 14: None}

# %%
dicts.setdefault("no",1785)  #adding key with a value
# Out:
# 1785

# %%
dicts
# Out:
# {'name': 'ayush', 'rollno': 14, 'class': 'btech', 14: None, 'no': 1785}

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# .zip() method using it to merge two lists in one and using dict to convert it into dictionary
# Method : dictionary_name = dict(zip(keys,values))

# %%
name = {"ayush","jay","arun"}

# %%
roll_no = {11,15,9}

# %%
data = dict(zip(name,roll_no))

# %%
data
# Out:
# {'jay': 9, 'ayush': 11, 'arun': 15}

# %%
#if i do not convert the list in dict than

# %%
data = zip(name,roll_no)
print(data)

# %% [markdown]
# # Dictionary Built-in Functions

# %% [markdown]
# ![Screenshot%202021-09-30%20at%2015-33-19%20Python%20Dictionary%20%28With%20Examples%29.png](attachment:Screenshot%202021-09-30%20at%2015-33-19%20Python%20Dictionary%20%28With%20Examples%29.png)

# %%
languages = { "second":'Java',"first":'Python',"subsecond":'JavaScript'}

# %%
len(languages)
# Out:
# 3

# %% [markdown]
# ### all method

# %% [markdown]
# ![Screenshot%202021-09-30%20at%2015-39-31%20Python%20all%28%29.png](attachment:Screenshot%202021-09-30%20at%2015-39-31%20Python%20all%28%29.png)

# %%
s = {0: 'False', 1: 'False'}
print(all(s))


s = {1: 'True', 2: 'True'}
print(all(s))

s = {1: 'True', False: 0}
print(all(s))


s = {}
print(all(s))
# Out:
# False
# True
# False
# True

# %% [markdown]
# #any() method
# ![Screenshot%202021-09-30%20at%2017-42-04%20Python%20any%28%29.png](attachment:Screenshot%202021-09-30%20at%2017-42-04%20Python%20any%28%29.png)

# %%
# 0 is False
d = {0: 'False'}
print(any(d))

# 1 is True
d = {0: 'False', 1: 'True'}
print(any(d))


# 0 and False are false
d = {0: 'False', False: 0}
print(any(d))

# iterable is empty
d = {}
print(any(d))

# '0' is True
d = {'0': 'true'}
print(any(d))
# Out:
# False
# True
# False
# False
# True

# %% [markdown]
# ### sorted method

# %%
dic = {1:"a",3:'c',2:"b"}

# %%
sorted(dic)       #sorting all key & it is not a permanet chnage
# Out:
# [1, 2, 3]

# %%
#OR

# %%
sorted(dic.keys())
# Out:
# [1, 2, 3]

# %%
sorted(dic.values()) #sorting all values
# Out:
# ['a', 'b', 'c']

# %%
sorted(dic.items())  # sorting both keys and values
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c')]

# %% [raw]
# differnce b/t any and all that
# any means one elemenet is true
# and all means all elmeents should be true

# %% [markdown]
# ## Nesting with Dictionaries
#
# Hopefully you're starting to see how powerful Python is with its flexibility of nesting objects and calling methods on them. Let's see a dictionary nested inside a dictionary:

# %% [markdown]
# METHOD:
# DIC = {"K1":{"v1":{"K2":"V2"}}}

# %%
dic1 = {"k1":1,"k2":{"m1":1,"m2":4}}

# %%
#now grabing a subkey value

# %%
dic1["k2"]["m1"]
# Out:
# 1

# %%
#another example

# %%
dic2 = {"m1":{"z1":{"y1":{"k1":1.2 + 25 }}}}  # a little bit complex one!!

# %%
dic2["m1"]["z1"]["y1"]["k1"]
# Out:
# 26.2

# %%
#note you cannot grab a subkey value directly

# %%
dic2["k1"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-165-96abdcebadd6> in <module>
# ----> 1 dic2["k1"]
#
# KeyError: 'k1'

# %% [markdown]
# # Extra info

# %% [markdown]
# ![Screenshot%202021-09-28%20at%2000-10-07%20%20%E2%80%93%20Real%20Python.png](attachment:Screenshot%202021-09-28%20at%2000-10-07%20%20%E2%80%93%20Real%20Python.png)

# %% [markdown]
# ![Screenshot%202021-09-28%20at%2000-11-44%20Dictionaries%20in%20Python%20%E2%80%93%20Real%20Python.png](attachment:Screenshot%202021-09-28%20at%2000-11-44%20Dictionaries%20in%20Python%20%E2%80%93%20Real%20Python.png)

# %% [markdown]
# ![Screenshot%202021-09-28%20at%2000-19-01%20%20%E2%80%93%20Real%20Python.png](attachment:Screenshot%202021-09-28%20at%2000-19-01%20%20%E2%80%93%20Real%20Python.png)#
